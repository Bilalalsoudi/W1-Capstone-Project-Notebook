# %% [markdown]
# # Week 3 assignmnet - Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# # Install geocoder

# %%
import sys
# !{sys.executable} -m pip install geocoder
# !{sys.executable} -m pip install folium

print('Packages installed.')
# Out:
# ...
# Packages installed.

# %% [markdown]
# # install BeautifulSoup4

# %%
pip install BeautifulSoup4
# Out:
# ...
#      |████████████████████████████████| 122kB 6.3MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import geocoder # import geocoder
import requests 
from bs4 import BeautifulSoup 

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # Q2 - Scrape Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of # postal codes and to transform the data into a pandas dataframe

# %%
import requests 
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source, 'html5lib')
table = soup.find('table',{'class':'wikitable sortable'})
print('Page Scrapped.')
# Out:
# Page Scrapped.

# %% [markdown]
# # Display data scraped from WIKI page

# %%
from IPython.display import display_html
tab = str(soup.table)
display_html(tab,raw=True)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Postal Code
# </th>
# <th>Borough
# </th>
# <th>Neighborhood
# </th></tr>
# <tr>
# <td>M1A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3A
# </td>
# <td>North York
# </td>
# <td>Parkwoods
# </td></tr>
# <tr>
# <td>M4A
# </td>
# <td>North York
# </td>
# <td>Victoria Village
# </td></tr>
# <tr>
# <td>M5A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Regent Park, Harbourfront
# </td></tr>
# <tr>
# <td>M6A
# </td>
# <td>North York
# </td>
# <td>Lawrence Manor, Lawrence Heights
# </td></tr>
# <tr>
# <td>M7A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Queen's Park, Ontario Provincial Government
# </td></tr>
# <tr>
# <td>M8A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9A
# </td>
# <td>Etobicoke
# </td>
# <td>Islington Avenue, Humber Valley Village
# </td></tr>
# <tr>
# <td>M1B
# ...

# %% [markdown]
# # Q3-1 Exporting scraped data into Data Frame. The data frame will consist of three columns: PostalCode, Borough, and Neighborhood

# %%
table_rows = table.find_all('tr')
data = []
for row in table_rows:
    data.append([t.text.strip() for t in row.find_all('td')])
df = pd.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighbourhood'])
df
# Out:
#     PostalCode           Borough  \
# 0         None              None
# 1          M1A      Not assigned
# 2          M2A      Not assigned
# 3          M3A        North York
# 4          M4A        North York
# 5          M5A  Downtown Toronto
# 6          M6A        North York
# 7          M7A  Downtown Toronto
# 8          M8A      Not assigned
# 9          M9A         Etobicoke
# 10         M1B       Scarborough
# 11         M2B      Not assigned
# 12         M3B        North York
# 13         M4B         East York
# 14         M5B  Downtown Toronto
# 15         M6B        North York
# 16         M7B      Not assigned
# 17         M8B      Not assigned
# 18         M9B         Etobicoke
# 19         M1C       Scarborough
# 20         M2C      Not assigned
# 21         M3C        North York
# 22         M4C         East York
# 23         M5C  Downtown Toronto
# 24         M6C              York
# 25         M7C      Not assigned
# 26         M8C      Not assigned
# ...

# %%
df.shape
# Out:
# (180, 3)

# %% [markdown]
# # Q3-2 More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.

# %%
# Checking if duplicate postal codes exsist ..No out put = no duplicate postal code 
df[df.duplicated(['PostalCode'])]
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# # Q3-3 Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
# Dropping the rows where column Borough has value of 'Not assigned'
df1 = df[df.Borough != 'Not assigned']
df1 = df1.reset_index()
df1
# Out:
#      index PostalCode           Borough  \
# 0        3        M3A        North York
# 1        4        M4A        North York
# 2        5        M5A  Downtown Toronto
# 3        6        M6A        North York
# 4        7        M7A  Downtown Toronto
# 5        9        M9A         Etobicoke
# 6       10        M1B       Scarborough
# 7       12        M3B        North York
# 8       13        M4B         East York
# 9       14        M5B  Downtown Toronto
# 10      15        M6B        North York
# 11      18        M9B         Etobicoke
# 12      19        M1C       Scarborough
# 13      21        M3C        North York
# 14      22        M4C         East York
# 15      23        M5C  Downtown Toronto
# 16      24        M6C              York
# 17      27        M9C         Etobicoke
# 18      28        M1E       Scarborough
# 19      31        M4E      East Toronto
# 20      32        M5E  Downtown Toronto
# 21      33        M6E              York
# ...

# %%
df1.shape
# Out:
# (103, 4)

# %% [markdown]
# # Q3-4 If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.

# %%
df1.loc[df1['Neighbourhood']=="Not assigned",'Neighbourhood']=df1.loc[df1['Neighbourhood']=="Not assigned",'Borough']
df1
# Out:
#      index PostalCode           Borough  \
# 0        3        M3A        North York
# 1        4        M4A        North York
# 2        5        M5A  Downtown Toronto
# 3        6        M6A        North York
# 4        7        M7A  Downtown Toronto
# 5        9        M9A         Etobicoke
# 6       10        M1B       Scarborough
# 7       12        M3B        North York
# 8       13        M4B         East York
# 9       14        M5B  Downtown Toronto
# 10      15        M6B        North York
# 11      18        M9B         Etobicoke
# 12      19        M1C       Scarborough
# 13      21        M3C        North York
# 14      22        M4C         East York
# 15      23        M5C  Downtown Toronto
# 16      24        M6C              York
# 17      27        M9C         Etobicoke
# 18      28        M1E       Scarborough
# 19      31        M4E      East Toronto
# 20      32        M5E  Downtown Toronto
# 21      33        M6E              York
# ...

# %%
df1.shape
# Out:
# (103, 4)

# %% [markdown]
# # Get the latitude and the longitude coordinates of each neighborhood and update the data frame to add two new columns for latitude and the longitude coordinates of each neighborhood

# %% [markdown]
# # Step 1 - Importing the csv file conatining the latitudes and longitudes for various neighbourhoods in Canada

# %%
df_lat = pd.read_csv('https://cocl.us/Geospatial_data')
df_lat
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %%
df_lat.shape
# Out:
# (103, 3)

# %% [markdown]
# # Step 2 - Merging the two tables for getting the Latitudes and Longitudes for various neighbourhoods in Canada

# %%
df_lat.rename(columns={'Postal Code': 'PostalCode'}, inplace=True)
df2 = pd.merge(df1,df_lat,on='PostalCode')
df2
# Out:
#      index PostalCode           Borough  \
# 0        3        M3A        North York
# 1        4        M4A        North York
# 2        5        M5A  Downtown Toronto
# 3        6        M6A        North York
# 4        7        M7A  Downtown Toronto
# 5        9        M9A         Etobicoke
# 6       10        M1B       Scarborough
# 7       12        M3B        North York
# 8       13        M4B         East York
# 9       14        M5B  Downtown Toronto
# 10      15        M6B        North York
# 11      18        M9B         Etobicoke
# 12      19        M1C       Scarborough
# 13      21        M3C        North York
# 14      22        M4C         East York
# 15      23        M5C  Downtown Toronto
# 16      24        M6C              York
# 17      27        M9C         Etobicoke
# 18      28        M1E       Scarborough
# 19      31        M4E      East Toronto
# 20      32        M5E  Downtown Toronto
# 21      33        M6E              York
# ...

# %% [markdown]
# # Explore and cluster the neighborhoods in Toronto. You can decide to work with only boroughs that contain the word Toronto and then replicate the same analysis we did to the New York City data

# %%
df3 = df2[df2['Borough'].str.contains('Toronto',regex=False)]
df3
# Out:
#      index PostalCode           Borough  \
# 2        5        M5A  Downtown Toronto
# 4        7        M7A  Downtown Toronto
# 9       14        M5B  Downtown Toronto
# 15      23        M5C  Downtown Toronto
# 19      31        M4E      East Toronto
# 20      32        M5E  Downtown Toronto
# 24      41        M5G  Downtown Toronto
# 25      42        M6G  Downtown Toronto
# 30      50        M5H  Downtown Toronto
# 31      51        M6H      West Toronto
# 36      59        M5J  Downtown Toronto
# 37      60        M6J      West Toronto
# 41      67        M4K      East Toronto
# 42      68        M5K  Downtown Toronto
# 43      69        M6K      West Toronto
# 47      76        M4L      East Toronto
# 48      77        M5L  Downtown Toronto
# 54      85        M4M      East Toronto
# 61      94        M4N   Central Toronto
# 62      95        M5N   Central Toronto
# 67     103        M4P   Central Toronto
# 68     104        M5P   Central Toronto
# ...

# %% [markdown]
# # Map Toronoto based naigborhood (Visualize)

# %%
map_toronto = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

for lat,lng,borough,neighbourhood in zip(df3['Latitude'],df3['Longitude'],df3['Borough'],df3['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
